# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

import numpy as np
import pandas as pd

# %%
data = pd.read_excel ('DummyData.xlsx')
labels = np.array (data.pop ('Dark Count'))
data = np.array (data)
training_size = (int)(data.size * 0.8)

# %%
training_data = data [0:training_size]
training_labels = labels [0:training_size]
testing_data = data [training_size:]
testing_labels = labels [training_size:]

# %%
normalizer = preprocessing.Normalization()

normalizer.adapt(np.array(training_data))

model = tf.keras.Sequential ([
    normalizer,
    layers.Dense (32, activation='relu'),
    layers.Dense (32, activation='relu'),
    layers.Dense (1)
])

# %%
loss = keras.losses.MeanAbsoluteError ()
metrics = ['accuracy']
model.compile (loss = loss, optimizer = tf.keras.optimizers.Adam (0.001), metrics = metrics)
print (model.summary ())

model.fit (training_data, training_labels, epochs = 100, verbose = 2, validation_data = (testing_data, testing_labels))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 4)                 9
# _________________________________________________________________
# dense (Dense)                (None, 32)                160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,258
# Trainable params: 1,249
# Non-trainable params: 9
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 - 2s - loss: 0.6928 - accuracy: 0.4286
# Epoch 2/100
# 1/1 - 0s - loss: 0.6688 - accuracy: 0.4286
# Epoch 3/100
# 1/1 - 0s - loss: 0.6500 - accuracy: 0.4286
# Epoch 4/100
# 1/1 - 0s - loss: 0.6309 - accuracy: 0.4286
# Epoch 5/100
# 1/1 - 0s - loss: 0.6129 - accuracy: 0.4286
# Epoch 6/100
# 1/1 - 0s - loss: 0.5957 - accuracy: 0.4286
# Epoch 7/100
# 1/1 - 0s - loss: 0.5791 - accuracy: 0.4286
# Epoch 8/100
# 1/1 - 0s - loss: 0.5653 - accuracy: 0.4286
# Epoch 9/100
# 1/1 - 0s - loss: 0.5552 - accuracy: 0.4286
# Epoch 10/100
# 1/1 - 0s - loss: 0.5439 - accuracy: 0.4286
# Epoch 11/100
# 1/1 - 0s - loss: 0.5352 - accuracy: 0.4286
# Epoch 12/100
# 1/1 - 0s - loss: 0.5257 - accuracy: 0.4286
# Epoch 13/100
# 1/1 - 0s - loss: 0.5159 - accuracy: 0.4286
# Epoch 14/100
# 1/1 - 0s - loss: 0.5057 - accuracy: 0.4286
# Epoch 15/100
# 1/1 - 0s - loss: 0.4952 - accuracy: 0.4286
# Epoch 16/100
# 1/1 - 0s - loss: 0.4869 - accuracy: 0.4286
# Epoch 17/100
# 1/1 - 0s - loss: 0.4791 - accuracy: 0.4286
# Epoch 18/100
# 1/1 - 0s - loss: 0.4715 - accuracy: 0.4286
# Epoch 19/100
# 1/1 - 0s - loss: 0.4651 - accuracy: 0.4286
# Epoch 20/100
# 1/1 - 0s - loss: 0.4591 - accuracy: 0.5000
# Epoch 21/100
# 1/1 - 0s - loss: 0.4527 - accuracy: 0.5000
# Epoch 22/100
# 1/1 - 0s - loss: 0.4461 - accuracy: 0.5000
# Epoch 23/100
# 1/1 - 0s - loss: 0.4392 - accuracy: 0.5000
# Epoch 24/100
# 1/1 - 0s - loss: 0.4320 - accuracy: 0.5000
# Epoch 25/100
# 1/1 - 0s - loss: 0.4244 - accuracy: 0.5000
# Epoch 26/100
# 1/1 - 0s - loss: 0.4166 - accuracy: 0.5000
# Epoch 27/100
# 1/1 - 0s - loss: 0.4122 - accuracy: 0.5000
# Epoch 28/100
# 1/1 - 0s - loss: 0.4056 - accuracy: 0.5714
# Epoch 29/100
# 1/1 - 0s - loss: 0.3972 - accuracy: 0.5714
# Epoch 30/100
# 1/1 - 0s - loss: 0.3891 - accuracy: 0.5714
# Epoch 31/100
# 1/1 - 0s - loss: 0.3812 - accuracy: 0.5714
# Epoch 32/100
# 1/1 - 0s - loss: 0.3726 - accuracy: 0.5714
# Epoch 33/100
# 1/1 - 0s - loss: 0.3653 - accuracy: 0.6429
# Epoch 34/100
# 1/1 - 0s - loss: 0.3578 - accuracy: 0.6429
# Epoch 35/100
# 1/1 - 0s - loss: 0.3509 - accuracy: 0.6429
# Epoch 36/100
# 1/1 - 0s - loss: 0.3426 - accuracy: 0.7143
# Epoch 37/100
# 1/1 - 0s - loss: 0.3355 - accuracy: 0.7143
# Epoch 38/100
# 1/1 - 0s - loss: 0.3289 - accuracy: 0.7143
# Epoch 39/100
# 1/1 - 0s - loss: 0.3219 - accuracy: 0.7143
# Epoch 40/100
# 1/1 - 0s - loss: 0.3143 - accuracy: 0.7857
# Epoch 41/100
# 1/1 - 0s - loss: 0.3063 - accuracy: 0.7857
# Epoch 42/100
# 1/1 - 0s - loss: 0.3003 - accuracy: 0.7857
# Epoch 43/100
# 1/1 - 0s - loss: 0.2951 - accuracy: 0.7857
# Epoch 44/100
# 1/1 - 0s - loss: 0.2890 - accuracy: 0.7857
# Epoch 45/100
# 1/1 - 0s - loss: 0.2827 - accuracy: 0.7143
# Epoch 46/100
# 1/1 - 0s - loss: 0.2788 - accuracy: 0.7143
# Epoch 47/100
# 1/1 - 0s - loss: 0.2745 - accuracy: 0.7143
# Epoch 48/100
# 1/1 - 0s - loss: 0.2699 - accuracy: 0.7143
# Epoch 49/100
# 1/1 - 0s - loss: 0.2650 - accuracy: 0.7143
# Epoch 50/100
# 1/1 - 0s - loss: 0.2588 - accuracy: 0.7143
# Epoch 51/100
# 1/1 - 0s - loss: 0.2525 - accuracy: 0.7143
# Epoch 52/100
# 1/1 - 0s - loss: 0.2460 - accuracy: 0.7857
# Epoch 53/100
# 1/1 - 0s - loss: 0.2419 - accuracy: 0.7857
# Epoch 54/100
# 1/1 - 0s - loss: 0.2372 - accuracy: 0.7857
# Epoch 55/100
# 1/1 - 0s - loss: 0.2321 - accuracy: 0.7857
# Epoch 56/100
# 1/1 - 0s - loss: 0.2266 - accuracy: 0.9286
# Epoch 57/100
# 1/1 - 0s - loss: 0.2204 - accuracy: 0.9286
# Epoch 58/100
# 1/1 - 0s - loss: 0.2137 - accuracy: 0.9286
# Epoch 59/100
# 1/1 - 0s - loss: 0.2089 - accuracy: 0.9286
# Epoch 60/100
# 1/1 - 0s - loss: 0.2060 - accuracy: 0.9286
# Epoch 61/100
# 1/1 - 0s - loss: 0.2022 - accuracy: 0.9286
# Epoch 62/100
# 1/1 - 0s - loss: 0.1992 - accuracy: 0.9286
# Epoch 63/100
# 1/1 - 0s - loss: 0.1952 - accuracy: 0.9286
# Epoch 64/100
# 1/1 - 0s - loss: 0.1908 - accuracy: 0.9286
# Epoch 65/100
# 1/1 - 0s - loss: 0.1870 - accuracy: 0.9286
# Epoch 66/100
# 1/1 - 0s - loss: 0.1837 - accuracy: 0.9286
# Epoch 67/100
# 1/1 - 0s - loss: 0.1802 - accuracy: 0.9286
# Epoch 68/100
# 1/1 - 0s - loss: 0.1764 - accuracy: 0.9286
# Epoch 69/100
# 1/1 - 0s - loss: 0.1722 - accuracy: 0.9286
# Epoch 70/100
# 1/1 - 0s - loss: 0.1680 - accuracy: 0.9286
# Epoch 71/100
# 1/1 - 0s - loss: 0.1634 - accuracy: 0.9286
# Epoch 72/100
# 1/1 - 0s - loss: 0.1596 - accuracy: 0.9286
# Epoch 73/100
# 1/1 - 0s - loss: 0.1551 - accuracy: 0.9286
# Epoch 74/100
# 1/1 - 0s - loss: 0.1513 - accuracy: 0.9286
# Epoch 75/100
# 1/1 - 0s - loss: 0.1474 - accuracy: 0.9286
# Epoch 76/100
# 1/1 - 0s - loss: 0.1430 - accuracy: 0.9286
# Epoch 77/100
# 1/1 - 0s - loss: 0.1404 - accuracy: 0.9286
# Epoch 78/100
# 1/1 - 0s - loss: 0.1356 - accuracy: 0.9286
# Epoch 79/100
# 1/1 - 0s - loss: 0.1316 - accuracy: 0.9286
# Epoch 80/100
# 1/1 - 0s - loss: 0.1276 - accuracy: 0.9286
# Epoch 81/100
# 1/1 - 0s - loss: 0.1250 - accuracy: 0.9286
# Epoch 82/100
# 1/1 - 0s - loss: 0.1193 - accuracy: 0.9286
# Epoch 83/100
# 1/1 - 0s - loss: 0.1172 - accuracy: 0.9286
# Epoch 84/100
# 1/1 - 0s - loss: 0.1130 - accuracy: 0.9286
# Epoch 85/100
# 1/1 - 0s - loss: 0.1092 - accuracy: 0.9286
# Epoch 86/100
# 1/1 - 0s - loss: 0.1071 - accuracy: 0.9286
# Epoch 87/100
# 1/1 - 0s - loss: 0.1032 - accuracy: 0.9286
# Epoch 88/100
# 1/1 - 0s - loss: 0.0987 - accuracy: 0.9286
# Epoch 89/100
# 1/1 - 0s - loss: 0.0972 - accuracy: 0.9286
# Epoch 90/100
# 1/1 - 0s - loss: 0.0933 - accuracy: 0.9286
# Epoch 91/100
# 1/1 - 0s - loss: 0.0883 - accuracy: 0.9286
# Epoch 92/100
# 1/1 - 0s - loss: 0.0852 - accuracy: 0.9286
# Epoch 93/100
# 1/1 - 0s - loss: 0.0838 - accuracy: 0.9286
# Epoch 94/100
# 1/1 - 0s - loss: 0.0822 - accuracy: 0.9286
# Epoch 95/100
# 1/1 - 0s - loss: 0.0790 - accuracy: 0.9286
# Epoch 96/100
# 1/1 - 0s - loss: 0.0802 - accuracy: 0.9286
# Epoch 97/100
# 1/1 - 0s - loss: 0.0814 - accuracy: 0.9286
# Epoch 98/100
# 1/1 - 0s - loss: 0.0807 - accuracy: 0.9286
# Epoch 99/100
# 1/1 - 0s - loss: 0.0813 - accuracy: 0.9286
# Epoch 100/100
# 1/1 - 0s - loss: 0.0808 - accuracy: 0.9286
